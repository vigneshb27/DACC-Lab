# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
df = pd.read_csv('Life_Expectancy_Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df = df.dropna(subset = ['Alcohol', 'Life_expectancy', 'Adult_Mortality', 'BMI', 'Total_expenditure', 'under_five_deaths'])

# %%
df.isnull().sum()
# Out:
# Year                                 0
# Life_expectancy                      0
# Adult_Mortality                      0
# infant_deaths                        0
# Alcohol                              0
# percentage_expenditure               0
# Hepatitis_B                        507
# Measles                              0
# BMI                                  0
# under_five_deaths                    0
# Polio                                7
# Total_expenditure                    0
# Diphtheria                           7
# HIV/AIDS                             0
# GDP                                375
# Population                         573
# thinness_1_to_19_years               0
# thinness_5_to_9_years                0
# Income_composition_of_resources    120
# Schooling                          120
# dtype: int64

# %%
df = df.drop('Country', axis=1)
df = df.drop('Status', axis=1)

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
independent_vars = ['percentage_expenditure', 'Adult_Mortality', 'infant_deaths', 'BMI', 'under_five_deaths', 'Alcohol', 'Measles']
features = df[independent_vars]
res = df['Life_expectancy']
X_train,X_test,y_train,y_test=train_test_split(features,res,test_size=0.3)

# %%
model=LinearRegression()
fittedModel=model.fit(X_train,y_train)
predictions=fittedModel.predict(X_test)
fittedModel.score(X_test,y_test)
# Out:
# 0.7228643476402414
