# %%
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv("collegePlace.csv")

# %%
X = df.loc[:,"Hostel":]
X.apply(np.mean)
# Out:
# Hostel               0.269049
# HistoryOfBacklogs    0.192178
# PlacedOrNot          0.552596
# dtype: float64

# %%
X.apply(np.max)
# Out:
# Hostel               1
# HistoryOfBacklogs    1
# PlacedOrNot          1
# dtype: int64

# %%
#Calculating Correlations for Multivariate Data
from scipy import stats

corr = stats.pearsonr(X.Hostel, X.PlacedOrNot)
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 0.03758689461614957
# cor:		 -0.0381823687882002

# %%
corrmat = X.corr()
corrmat
# Out:
#                      Hostel  HistoryOfBacklogs  PlacedOrNot
# Hostel             1.000000           0.103506    -0.038182
# HistoryOfBacklogs  0.103506           1.000000    -0.022337
# PlacedOrNot       -0.038182          -0.022337     1.000000

# %%
sns.pairplot(df, hue = "PlacedOrNot")
