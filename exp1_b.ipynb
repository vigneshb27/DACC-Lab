# %%
with open("demo.txt") as f:
 lines = f.readlines()
 count = 0
 for line in lines:
     count+=1
 print("Number of lines : {}".format(count))
# Out:
# Number of lines : 3

# %%
import pandas as pd
read_file = pd.read_excel("collegePlace2.xlsx")
read_file.to_csv("collegePlace.csv", index = None, header = True)

# %%
import csv
with open("collegePlace.csv") as f:
 reader = csv.reader(f)
 for line in reader:
     print(line)
# Out:
# ['Age', 'Gender', 'Stream', 'Internships', 'CGPA', 'Hostel', 'HistoryOfBacklogs', 'PlacedOrNot']
# ['22', 'Male', 'Electronics And Communication', '1', '8', '1', '1', '1']
# ['21', 'Female', 'Computer Science', '0', '7', '1', '1', '1']
# ['22', 'Female', 'Information Technology', '1', '6', '0', '0', '1']
# ['21', 'Male', 'Information Technology', '0', '8', '0', '1', '1']
# ['22', 'Male', 'Mechanical', '0', '8', '1', '0', '1']
# ['22', 'Male', 'Electronics And Communication', '0', '6', '0', '0', '0']
# ['21', 'Male', 'Computer Science', '0', '7', '0', '1', '0']
# ['21', 'Male', 'Information Technology', '1', '7', '0', '0', '0']
# ['21', 'Male', 'Computer Science', '2', '6', '0', '0', '1']
# ['21', 'Female', 'Computer Science', '1', '6', '1', '0', '0']
# ['22', 'Male', 'Computer Science', '1', '8', '0', '0', '0']
# ['22', 'Female', 'Electrical', '1', '8', '0', '1', '1']
# ['21', 'Female', 'Computer Science', '2', '6', '1', '1', '0']
# ...

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.geeksforgeeks.org/reading-rows-from-a-csv-file-in-python/")
soup = BeautifulSoup (r.content, 'html.parser')
lines = soup.find_all('p')
for line in lines:
    print(line.text)
# Out:
# CSV stands for Comma Separated Values. This file format is a delimited text file that uses a comma as a delimiter to separate the text present in it. Or in other words, CSV files are used to store data in tabular form. As per the name suggested, this file contains the data which is separated by a comma and every line of a file is considered a record. We can create the CSV file either from notepad or using excel.
# Example:
# We can create a CSV file using the following ways:
# 1. Using Notepad: We can create a CSV file using Notepad. In the Notepad, open a new file in which separate the values by comma and save the file with .csv extension.
#
# 2. Using Excel: We can also create a CSV file using Excel. In Excel, open a new file in which specify each value in a different cell and save it with filetype CSV.
#
# To read data row-wise from a CSV file in Python, we can use reader and DictReader which are present in the CSV module allows us to fetch data row-wise.
# ...
